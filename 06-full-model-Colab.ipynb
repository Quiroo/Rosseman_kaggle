# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
pip install pandas_summary
# Out:
# Collecting pandas_summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: pandas-summary
# Successfully installed pandas-summary-0.0.7

# %%
import pandas as pd
import numpy as np
import datetime

from pandas_summary import DataFrameSummary

# %%
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_feather('train_normalized_data.fth')
df_test = pd.read_feather('test_normalized_data.fth')

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo2Weeks', 
            'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 
            'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw']

cat_vars = ['Store', 'DayOfWeek']

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Promo', 'SchoolHoliday', 'StateHoliday_bool']
contin_vars = ['BeforeStateHoliday_bool', 'Max_TemperatureC']

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]

# %%
uniques.T
# Out:
#           uniques
# Store        1115
# DayOfWeek       7

# %% [markdown]
# # Asignación de dimensión de embeddings

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 2, 'Year': 2, 'Month': 2,
'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
'Week': 25, 'Events': 4, 'Promo_fw': 1,
'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
'SchoolHoliday_bw': 1}

# %%
for v in cat_vars:
    uniques_ = df[v].unique()
    uniques_.sort()
    print(v, cat_var_dict[v], len(uniques_), uniques_)
    print()
# Out:
# Store 50 1115 [   0    1    2 ... 1112 1113 1114]
#
# DayOfWeek 2 7 [0 1 2 3 4 5 6]

# %% [markdown]
# # Definición de modelo

# %%
add_customers = True
log_output = False
output_activation = 'linear'

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2

# %%
def get_cat_vars_model(cat_vars, uniques, cat_var_dict):
    cat_vars_embed_outs = []
    cat_var_inputs = []
    for cat_var in cat_vars:
        cat_var_in = Input(shape=(1,), name=f"{cat_var}_input")
        cat_var_inputs.append(cat_var_in)
        embed_out = Embedding(uniques[cat_var][0], cat_var_dict[cat_var], name=f'{cat_var}_Embed')(cat_var_in)
        flatten_out = Flatten(name=f"{cat_var}_flat")(embed_out)
        cat_vars_embed_outs.append(flatten_out)
    return cat_var_inputs, cat_vars_embed_outs

def get_cont_vars_input(contin_vars, dense_layer=False):
    cont_vars_inputs = []
    cont_vars_outputs = []
    for cont_var in contin_vars:
        cont_var_in = Input(shape=(1,), name=f"{cont_var}_input")
        cont_vars_inputs.append(cont_var_in)
        if dense_layer:
            cont_var_out = Dense(1, name=f"{cont_var}_input", activation = 'linear')(cont_var_in)
            cont_vars_outputs.append(cont_var_out)
        else:
            cont_vars_outputs.append(cont_var_in)
    return cont_vars_inputs, cont_vars_outputs

# %%
cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model(cat_vars, uniques, cat_var_dict)
cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars)

# %%
# Descomentar para ver resultados
# cat_vars_embed_outs
# cat_var_inputs
# cont_vars_inputs
cont_vars_outs
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'BeforeStateHoliday_bool_input')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Max_TemperatureC_input')>]

# %%
first_hidden_units = 1000
second_hidden_units = 500
l2_lambda = 1e-3
merged = Concatenate(name='All_Concatenate')(cat_vars_embed_outs + cont_vars_inputs)
x = Dense(first_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(merged)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)
x = Dense(second_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(x)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)

output_1 = Dense(1, name='Sales', activation=output_activation)(x)
output_2 = Dense(1, name='Customers', activation=output_activation)(x)

# %%
if add_customers:
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1, output_2])
else: 
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1])

# %%
# Descomentar para ver
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Store_input (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# DayOfWeek_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Store_Embed (Embedding)         (None, 1, 50)        55750       Store_input[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_Embed (Embedding)     (None, 1, 2)         14          DayOfWeek_input[0][0]
# __________________________________________________________________________________________________
# Store_flat (Flatten)            (None, 50)           0           Store_Embed[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_flat (Flatten)        (None, 2)            0           DayOfWeek_Embed[0][0]
# __________________________________________________________________________________________________
# BeforeStateHoliday_bool_input ( [(None, 1)]          0
# __________________________________________________________________________________________________
# Max_TemperatureC_input (InputLa [(None, 1)]          0
# __________________________________________________________________________________________________
# All_Concatenate (Concatenate)   (None, 54)           0           Store_flat[0][0]
#                                                                  DayOfWeek_flat[0][0]
#                                                                  BeforeStateHoliday_bool_input[0][
#                                                                  Max_TemperatureC_input[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1000)         55000       All_Concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1000)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 500)          500500      activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 500)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# Sales (Dense)                   (None, 1)            501         activation_1[0][0]
# __________________________________________________________________________________________________
# Customers (Dense)               (None, 1)            501         activation_1[0][0]
# ==================================================================================================
# Total params: 612,266
# Trainable params: 612,266
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save_weights('initial_weights.hdf5')

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
print(f'Cantidad en val: {len(df_val)}, porcentaje: {len(df_train)/(len(df_train) + len(df_val))}')
# Out:
# Cantidad en val: 30188, porcentaje: 0.9642465458145908

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,5))
plt.plot((df_train[df_train['Store']==1]['Sales'].values - df_train[df_train['Store']==1]['Sales'].mean())/df_train[df_train['Store']==1]['Sales'].std())
plt.show()
plt.figure(figsize=(20,5))
plt.plot(np.log(df_train[df_train['Store']==1]['Sales'].values)/np.max(np.log(df_train[df_train['Store']==1]['Sales'].values)))
plt.show()

# %%
stores_mean = {}
for store, g_df in df_train.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)

df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
from tensorflow.keras import backend as K

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

# %%
def get_metric(df, sales_):
    return np.sqrt((((df['Sales'] - sales_)/df['Sales'])**2).mean())

# %%
get_metric(df_val, df_val['mean_by_store'])
# Out:
# 0.30717460853388645

# %%
all_vars = cat_vars + contin_vars
X_train = np.hsplit(df_train[all_vars].values, len(all_vars))
X_val = np.hsplit(df_val[all_vars].values, len(all_vars))
X_test = np.hsplit(df_test[all_vars].values, len(all_vars))

# %%
if add_customers:
    y_out_columns = ['Sales', 'Customers']
else:
    y_out_columns = ['Sales_store']
    
if log_output:
    # Escala logaritmica
    max_log_y = np.max(np.log(df[y_out_columns])).values
    y_train = np.log(df_train[y_out_columns].values)/max_log_y
    y_val = np.log(df_val[y_out_columns].values)/max_log_y
else:
    # Normalización
    y_mean = df_train[y_out_columns].mean().values
    y_std = df_train[y_out_columns].std().values
    y_train = (df_train[y_out_columns].values - y_mean)/y_std
    y_val = (df_val[y_out_columns].values - y_mean)/y_std
    y_max = df_train[y_out_columns].max().values
    y_train = df_train[y_out_columns].values/y_max
    y_val = df_val[y_out_columns].values/y_max
y_train = np.hsplit(y_train, y_train.shape[1])
y_val = np.hsplit(y_val, y_val.shape[1])

# %%
lr = 0.001
model.compile(optimizer=Adam(lr=lr), metrics=['mse', rmspe], loss='mse')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
if add_customers:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_Sales_mse', verbose=1, save_best_only=True)
else:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
epochs = 20
batch_size = 256
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/20
# 3181/3181 - 74s - loss: 0.0065 - Sales_loss: 0.0023 - Customers_loss: 8.3686e-04 - Sales_mse: 0.0023 - Sales_rmspe: 0.3547 - Customers_mse: 8.3686e-04 - Customers_rmspe: 0.3188 - val_loss: 0.0026 - val_Sales_loss: 0.0017 - val_Customers_loss: 7.0411e-04 - val_Sales_mse: 0.0017 - val_Sales_rmspe: 0.2834 - val_Customers_mse: 7.0411e-04 - val_Customers_rmspe: 0.2859
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00169, saving model to bestmodel.hdf5
# Epoch 2/20
# 3181/3181 - 73s - loss: 0.0027 - Sales_loss: 0.0020 - Customers_loss: 5.3981e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.3281 - Customers_mse: 5.3981e-04 - Customers_rmspe: 0.2782 - val_loss: 0.0020 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.7048e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2557 - val_Customers_mse: 3.7048e-04 - val_Customers_rmspe: 0.2227
#
# Epoch 00002: val_Sales_mse improved from 0.00169 to 0.00143, saving model to bestmodel.hdf5
# Epoch 3/20
# 3181/3181 - 72s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.5425e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3218 - Customers_mse: 4.5425e-04 - Customers_rmspe: 0.2595 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4217e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2447 - val_Customers_mse: 3.4217e-04 - val_Customers_rmspe: 0.1956
#
# Epoch 00003: val_Sales_mse did not improve from 0.00143
# Epoch 4/20
# 3181/3181 - 72s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.5157e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3175 - Customers_mse: 4.5157e-04 - Customers_rmspe: 0.2556 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.6307e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2296 - val_Customers_mse: 3.6307e-04 - val_Customers_rmspe: 0.2095
#
# Epoch 00004: val_Sales_mse did not improve from 0.00143
# Epoch 5/20
# 3181/3181 - 72s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.4915e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3122 - Customers_mse: 4.4915e-04 - Customers_rmspe: 0.2522 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4605e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2501 - val_Customers_mse: 3.4605e-04 - val_Customers_rmspe: 0.2045
#
# Epoch 00005: val_Sales_mse improved from 0.00143 to 0.00139, saving model to bestmodel.hdf5
# Epoch 6/20
# 3181/3181 - 72s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4411e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3075 - Customers_mse: 4.4411e-04 - Customers_rmspe: 0.2477 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.3845e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2276 - val_Customers_mse: 3.3845e-04 - val_Customers_rmspe: 0.1833
#
# Epoch 00006: val_Sales_mse did not improve from 0.00139
# Epoch 7/20
# 3181/3181 - 72s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.3094e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3024 - Customers_mse: 4.3094e-04 - Customers_rmspe: 0.2379 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4494e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2363 - val_Customers_mse: 3.4494e-04 - val_Customers_rmspe: 0.1914
#
# Epoch 00007: val_Sales_mse did not improve from 0.00139
# Epoch 8/20
# 3181/3181 - 72s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.2123e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.2982 - Customers_mse: 4.2123e-04 - Customers_rmspe: 0.2289 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.2294e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2242 - val_Customers_mse: 3.2294e-04 - val_Customers_rmspe: 0.1814
#
# Epoch 00008: val_Sales_mse improved from 0.00139 to 0.00136, saving model to bestmodel.hdf5
# Epoch 9/20
# 3181/3181 - 72s - loss: 0.0023 - Sales_loss: 0.0018 - Customers_loss: 4.0469e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.2918 - Customers_mse: 4.0469e-04 - Customers_rmspe: 0.2196 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3721e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2170 - val_Customers_mse: 3.3721e-04 - val_Customers_rmspe: 0.1829
#
# Epoch 00009: val_Sales_mse improved from 0.00136 to 0.00134, saving model to bestmodel.hdf5
# Epoch 10/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.8068e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2850 - Customers_mse: 3.8068e-04 - Customers_rmspe: 0.2124 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3413e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2199 - val_Customers_mse: 3.3413e-04 - val_Customers_rmspe: 0.1805
#
# Epoch 00010: val_Sales_mse improved from 0.00134 to 0.00134, saving model to bestmodel.hdf5
# Epoch 11/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7469e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2828 - Customers_mse: 3.7469e-04 - Customers_rmspe: 0.2113 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 2.9975e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2136 - val_Customers_mse: 2.9975e-04 - val_Customers_rmspe: 0.1645
#
# Epoch 00011: val_Sales_mse improved from 0.00134 to 0.00131, saving model to bestmodel.hdf5
# Epoch 12/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7377e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2821 - Customers_mse: 3.7377e-04 - Customers_rmspe: 0.2106 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3702e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2295 - val_Customers_mse: 3.3702e-04 - val_Customers_rmspe: 0.1932
#
# Epoch 00012: val_Sales_mse did not improve from 0.00131
# Epoch 13/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7276e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2819 - Customers_mse: 3.7276e-04 - Customers_rmspe: 0.2105 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.6218e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2234 - val_Customers_mse: 3.6218e-04 - val_Customers_rmspe: 0.1869
#
# Epoch 00013: val_Sales_mse did not improve from 0.00131
# Epoch 14/20
# 3181/3181 - 73s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6945e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2814 - Customers_mse: 3.6945e-04 - Customers_rmspe: 0.2098 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 2.8802e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2065 - val_Customers_mse: 2.8802e-04 - val_Customers_rmspe: 0.1586
#
# Epoch 00014: val_Sales_mse did not improve from 0.00131
# Epoch 15/20
# 3181/3181 - 73s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7010e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2813 - Customers_mse: 3.7010e-04 - Customers_rmspe: 0.2097 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0744e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2266 - val_Customers_mse: 3.0744e-04 - val_Customers_rmspe: 0.1774
#
# Epoch 00015: val_Sales_mse improved from 0.00131 to 0.00131, saving model to bestmodel.hdf5
# Epoch 16/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6765e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2809 - Customers_mse: 3.6765e-04 - Customers_rmspe: 0.2093 - val_loss: 0.0017 - val_Sales_loss: 0.0014 - val_Customers_loss: 2.8094e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2102 - val_Customers_mse: 2.8094e-04 - val_Customers_rmspe: 0.1646
#
# Epoch 00016: val_Sales_mse did not improve from 0.00131
# Epoch 17/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6713e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2810 - Customers_mse: 3.6713e-04 - Customers_rmspe: 0.2094 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.2866e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2111 - val_Customers_mse: 3.2866e-04 - val_Customers_rmspe: 0.1867
#
# Epoch 00017: val_Sales_mse improved from 0.00131 to 0.00129, saving model to bestmodel.hdf5
# Epoch 18/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6699e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2808 - Customers_mse: 3.6699e-04 - Customers_rmspe: 0.2095 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 2.9753e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2113 - val_Customers_mse: 2.9753e-04 - val_Customers_rmspe: 0.1784
#
# Epoch 00018: val_Sales_mse did not improve from 0.00129
# Epoch 19/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6578e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2804 - Customers_mse: 3.6578e-04 - Customers_rmspe: 0.2091 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 2.9774e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2147 - val_Customers_mse: 2.9774e-04 - val_Customers_rmspe: 0.1742
#
# Epoch 00019: val_Sales_mse did not improve from 0.00129
# Epoch 20/20
# 3181/3181 - 72s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6661e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2806 - Customers_mse: 3.6661e-04 - Customers_rmspe: 0.2097 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0240e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2142 - val_Customers_mse: 3.0240e-04 - val_Customers_rmspe: 0.1842
#
# Epoch 00020: val_Sales_mse improved from 0.00129 to 0.00126, saving model to bestmodel.hdf5

# %%
plt.plot(history.history['val_loss'])
# plt.plot(history.history['val_Customers_mse'])
# plt.plot(history.history['val_Sales_mse'])
plt.show()
plt.plot(history.history['loss'])
# plt.plot(history.history['Customers_mse'])
# plt.plot(history.history['Sales_mse'])

# %% [markdown]
# # Métrica

# %% [markdown]
# $$
# \textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}
# $$

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 3s 3ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.0240e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2103 - Customers_mse: 3.0240e-04 - Customers_rmspe: 0.1801
# [0.0016593332402408123,
#  0.0012630501296371222,
#  0.00030240396154113114,
#  0.0012630501296371222,
#  0.21028445661067963,
#  0.00030240396154113114,
#  0.1800544559955597]

# %%
model.load_weights('bestmodel.hdf5')
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 3s 3ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.0240e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2103 - Customers_mse: 3.0240e-04 - Customers_rmspe: 0.1801
# [0.0016593332402408123,
#  0.0012630501296371222,
#  0.00030240396154113114,
#  0.0012630501296371222,
#  0.21028445661067963,
#  0.00030240396154113114,
#  0.1800544559955597]

# %%
# model.load_weights('bestmodel.hdf5')
# model.evaluate(X_val, y_val)
# 30188/30188 [==============================] - 5s 172us/step
# [0.12197033089921382,
#  0.07211007360268763,
#  0.037183713050426136,
#  0.07211007360268763,
#  0.037183713050426136]

# [0.12932546436786652,
#  0.07751645147800446,
#  0.039259567856788635,
#  0.07751645147800446,
#  0.039259567856788635]

# %%
if log_output:
    if add_customers:
        y_pred = np.exp(model.predict(X_val, verbose=1)[0][:, 0]*max_log_y[0])
        y_pred_test = np.exp(model.predict(X_test, verbose=1)[0][:, 0]*max_log_y[0])
    else:
        y_pred = np.exp(model.predict(X_val, verbose=1)*max_log_y)[:,0]
        y_pred_test = np.exp(model.predict(X_test, verbose=1)*max_log_y)[:,0]
else:
    if add_customers:
        y_pred = (model.predict(X_val, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
        y_pred_test = (model.predict(X_test, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
    else:
#         y_pred = model.predict(X_val, verbose=1)[:,0]*y_std + y_mean
#         y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_std + y_mean
        y_pred = model.predict(X_val, verbose=1)[:,0]*y_max
        y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_max
y_pred_test[df_test['Open'] == 0] = 0
# Out:
# 944/944 [==============================] - 2s 2ms/step
# 1284/1284 [==============================] - 4s 3ms/step

# %%
np.sqrt((((df_val['Sales'].values - y_pred)/df_val['Sales'].values)**2).sum()/len(y_pred))
# Out:
# 0.5856458628176896

# %%
y_pred_test[:10]
# Out:
# array([7314.5527, 7496.748 , 7630.616 , 7407.728 , 7472.1885, 7397.557 ,
#        7572.066 , 7497.5786, 7310.4956, 7405.7603], dtype=float32)

# %% [markdown]
# # Baseline

# %%
import pandas as pd
sample_csv = pd.read_csv('sample_submission.csv')

# %%
stores_mean = {}
for store, g_df in df.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_test['Sales'] = df_test['Store'].apply(stores_mean.get)
df_test.loc[df_test['Open'] == 0, 'Sales'] = 0

# %%
df_test[['Store', 'Sales']].head(10)
# Out:
#    Store        Sales
# 0      0  4759.096031
# 1      2  6942.568678
# 2      6  8817.050891
# 3      7  5539.358418
# 4      8  6562.337612
# 5      9  5568.420918
# 6     10  8030.977041
# 7     11  7589.598214
# 8     12  5034.747182
# 9     13  5508.567394

# %%
df_test[df_test['Open'] == 0][['Store', 'Sales']].head()
# Out:
#       Store  Sales
# 543     702    0.0
# 676     878    0.0
# 840    1096    0.0
# 1399    702    0.0
# 1532    878    0.0

# %%
sample_csv['Sales'] = df_test['Sales']

# %%
sample_csv.to_csv(f'submision_baseline.csv', index=False)

# %%
sample_csv.head()
# Out:
#    Id        Sales
# 0   1  4759.096031
# 1   2  6942.568678
# 2   3  8817.050891
# 3   4  5539.358418
# 4   5  6562.337612

# %% [markdown]
# # Sumbit a la competición

# %%
sample_csv = pd.read_csv('sample_submission.csv')
sample_csv['Sales'] = y_pred_test
sample_csv.head()

sample_csv.to_csv(f'submision_{add_customers}-{log_output}-{output_activation}-{l2_lambda}-{first_hidden_units}-{epochs}-{batch_size}-{lr}.csv', index=False)

# %% [markdown]
# # Analisis de embedings

# %%
def plot_embed(layer_name, cat_names):
    Y = model.get_layer(layer_name).get_weights()[0]
    print(Y.shape)
    plt.figure(figsize=(8,8))
    plt.scatter(-Y[:, 0], -Y[:, 1])
    for i, txt in enumerate(cat_names):
        plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
model.load_weights('bestmodel.hdf5')
plot_embed('DayOfWeek_Embed', ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun'])
# Out:
# (7, 2)

# %%
plot_embed('Month_Embed', list(range(12)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-c3dc3ee5fed0> in <module>()
# ----> 1 plot_embed('Month_Embed', list(range(12)))
#
# <ipython-input-52-52ee9a3c03b6> in plot_embed(layer_name, cat_names)
#       1 def plot_embed(layer_name, cat_names):
# ----> 2     Y = model.get_layer(layer_name).get_weights()[0]
#       3     print(Y.shape)
#       4     plt.figure(figsize=(8,8))
#       5     plt.scatter(-Y[:, 0], -Y[:, 1])
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in get_layer(self, name, index)
#    2566         if layer.name == name:
#    2567           return layer
# -> 2568       raise ValueError('No such layer: ' + name + '.')
#    2569     raise ValueError('Provide either a layer name or layer index.')
#    2570
#
# ValueError: No such layer: Month_Embed.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
day_of_week_embedding.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-00f84f4b7b18> in <module>()
# ----> 1 day_of_week_embedding.shape
#
# NameError: name 'day_of_week_embedding' is not defined

# %%
tsne = TSNE(n_components=2, random_state=1, learning_rate=10, n_iter=10000)
Y = tsne.fit_transform(day_of_week_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-05f8c2c9edfa> in <module>()
#       1 tsne = TSNE(n_components=2, random_state=1, learning_rate=10, n_iter=10000)
# ----> 2 Y = tsne.fit_transform(day_of_week_embedding)
#       3 names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
#       4 plt.figure(figsize=(8,8))
#       5 plt.scatter(-Y[:, 0], -Y[:, 1])
#
# NameError: name 'day_of_week_embedding' is not defined

# %%
cat_vars

# %% [markdown]
# ## Store embeddings

# %%
submodel = Model(cat_var_inputs + cont_vars_inputs, merged)

# %%
submodel.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Store_input (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# DayOfWeek_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Store_Embed (Embedding)         (None, 1, 50)        55750       Store_input[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_Embed (Embedding)     (None, 1, 2)         14          DayOfWeek_input[0][0]
# __________________________________________________________________________________________________
# Store_flat (Flatten)            (None, 50)           0           Store_Embed[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_flat (Flatten)        (None, 2)            0           DayOfWeek_Embed[0][0]
# __________________________________________________________________________________________________
# BeforeStateHoliday_bool_input ( [(None, 1)]          0
# __________________________________________________________________________________________________
# Max_TemperatureC_input (InputLa [(None, 1)]          0
# __________________________________________________________________________________________________
# All_Concatenate (Concatenate)   (None, 54)           0           Store_flat[0][0]
#                                                                  DayOfWeek_flat[0][0]
#                                                                  BeforeStateHoliday_bool_input[0][
#                                                                  Max_TemperatureC_input[0][0]
# ==================================================================================================
# Total params: 55,764
# Trainable params: 55,764
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
submodel.save('embeddings_model.hdf5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
